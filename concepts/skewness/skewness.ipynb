# %% [markdown]
# <table align="left" width=100%>
#     <tr>
#         <td width="12%">
#             <img src="../../images/RA_Logo.png">
#         </td>
#         <td>
#             <div align="center">
#                 <font color="#21618C" size=8px>
#                   <b> Skewness </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <table align="left">
#   <td>
#     <a href="https://colab.research.google.com/github/vidyadharbendre/learn_machine_learning/blob/main/concepts/skewness/skewness.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
#   </td>
#   <td>
#     <a target="_blank" href="https://kaggle.com/kernels/welcome?src=https://github.com/vidyadharbendre/learn_machine_learning/blob/main/concepts/skewness/skewness.ipynb"><img src="https://kaggle.com/static/images/open-in-kaggle.svg" /></a>
#   </td>
# </table>

# %% [markdown]
# ## Introduction to Skewness
# Skewness is a measure of the asymmetry of the probability distribution of a real-valued random variable about its mean. It describes the degree to which a dataset differs from a normal distribution.
#
# Positive Skewness: Also known as right-skewed, indicates that the tail on the right side of the distribution is longer or fatter than the left side. This means that the majority of the data values are concentrated on the left, with a few larger values stretching out to the right.
#
# Negative Skewness: Also known as left-skewed, indicates that the tail on the left side of the distribution is longer or fatter than the right side. This means that the majority of the data values are concentrated on the right, with a few smaller values stretching out to the left.
#
# Zero Skewness: Indicates a symmetric distribution.
#
# ## Why Use Skewness?
# Distribution Shape: It provides insight into the shape of the data distribution.
#
# Data Analysis: Helps in understanding whether the data is normally distributed.
#
# Modeling: Certain statistical models assume normality, and skewness helps check this assumption.
#
# Outlier Detection: Helps in identifying outliers that might affect the distribution.
#
# ## Example
# Assuming you have a DataFrame df with columns Temperature, Humidity, Pressure, and Wind Speed, here's how you can calculate and visualize the skewness:
#
# Step 1: Calculate the Skewness

# %%
import pandas as pd

# Example DataFrame
data = {
    'Temperature': [22, 21, 23, 24, 22, 20, 25],
    'Humidity': [30, 35, 28, 40, 36, 32, 31],
    'Pressure': [1012, 1010, 1015, 1011, 1013, 1009, 1014],
    'Wind Speed': [10, 12, 8, 14, 9, 11, 13]
}
df = pd.DataFrame(data)

# Calculate the skewness for the specified columns
skewness_values = df[['Temperature', 'Humidity', 'Pressure', 'Wind Speed']].skew()

# Create a DataFrame to display the skewness
skew_df = skewness_values.to_frame().reset_index()
skew_df.columns = ['Variable', 'Skewness']

print(skew_df)
# Out:
#       Variable  Skewness
# 0  Temperature  0.168964
# 1     Humidity  0.588276
# 2     Pressure  0.000000
# 3   Wind Speed  0.000000

# %% [markdown]
# Step 2: Visualize the Skewness

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Plot the skewness using a bar plot
plt.figure(figsize=(10, 6))
sns.barplot(x='Variable', y='Skewness', data=skew_df)
plt.title('Skewness of Variables')
plt.xlabel('Variables')
plt.ylabel('Skewness')
plt.show()

# %% [markdown]
# ## Full Code Example
# Here's the complete code in one place:

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Example DataFrame
data = {
    'Temperature': [22, 21, 23, 24, 22, 20, 25],
    'Humidity': [30, 35, 28, 40, 36, 32, 31],
    'Pressure': [1012, 1010, 1015, 1011, 1013, 1009, 1014],
    'Wind Speed': [10, 12, 8, 14, 9, 11, 13]
}
df = pd.DataFrame(data)

# Calculate the skewness for the specified columns
skewness_values = df[['Temperature', 'Humidity', 'Pressure', 'Wind Speed']].skew()

# Create a DataFrame to display the skewness
skew_df = skewness_values.to_frame().reset_index()
skew_df.columns = ['Variable', 'Skewness']

print(skew_df)

# Plot the skewness using a bar plot
plt.figure(figsize=(10, 6))
sns.barplot(x='Variable', y='Skewness', data=skew_df)
plt.title('Skewness of Variables')
plt.xlabel('Variables')
plt.ylabel('Skewness')
plt.show()
# Out:
#       Variable  Skewness
# 0  Temperature  0.168964
# 1     Humidity  0.588276
# 2     Pressure  0.000000
# 3   Wind Speed  0.000000

# %% [markdown]
# ## Interpretation of Skewness
#
# ### Temperatura_Media_C (-0.049255):
#
# Negative Skewness: Slightly left-skewed.
# Inference: The distribution of Temperatura_Media_C is approximately symmetric with a slight tendency towards lower values.
#
# ### Temperatura_Minima_C (-0.225035):
#
# Negative Skewness: Left-skewed.
# Inference: The distribution of Temperatura_Minima_C has a tendency towards lower values, with a longer tail on the left side.
#
# ### Temperatura_Maxima_C (-0.155435):
#
# Negative Skewness: Left-skewed.
# Inference: The distribution of Temperatura_Maxima_C has a tendency towards lower values, with a slightly longer tail on the left side.
#
# ### Precipitacao_mm (3.780119):
#
# Positive Skewness: Strongly right-skewed.
# Inference: The distribution of Precipitacao_mm has a strong tendency towards higher values, with a long tail on the right side. This suggests that there are occasional high precipitation values.
#
# ### Final_de_Semana (0.956871):
#
# Positive Skewness: Right-skewed.
# Inference: The distribution of Final_de_Semana has a tendency towards higher values, with a longer tail on the right side.
#
# ### Consumo_de_cerveja_litros (0.270268):
#
# Positive Skewness: Slightly right-skewed.
# Inference: The distribution of Consumo_de_cerveja_litros is approximately symmetric with a slight tendency towards higher values.
#
# ## Summary
# Slight Negative Skew (left-skewed): Temperatura_Media_C, Temperatura_Minima_C, Temperatura_Maxima_C
# These variables have distributions that are approximately symmetric but slightly skewed towards lower values.
#
# Strong Positive Skew (right-skewed): Precipitacao_mm
# This variable has a distribution with a long tail on the right, indicating occasional high values.
#
# Moderate Positive Skew (right-skewed): Final_de_Semana
# This variable has a noticeable skew towards higher values, with a longer tail on the right side.
#
# Slight Positive Skew (right-skewed): Consumo_de_cerveja_litros
# This variable has a distribution that is approximately symmetric but slightly skewed towards higher values.
#
# This analysis helps in understanding the distribution characteristics of each variable, which can inform further statistical analysis and decision-making.

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.16.1
